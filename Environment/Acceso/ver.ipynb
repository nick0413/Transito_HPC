# %%
import numpy as np
import matplotlib.pylab as plt 
import imageio.v3 as iio
import networkx as nx
from itertools import count

imagen=np.loadtxt("Acceso_100.csv",delimiter=",",dtype="float")
print(imagen[28,69])
plt.xlim(xmax=35,xmin=20)
plt.ylim(ymax=75,ymin=60)
plt.imshow(imagen)
# Out:
# 0.0
